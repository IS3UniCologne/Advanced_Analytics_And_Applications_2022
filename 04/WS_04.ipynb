# %% [markdown]
# # Workshop 05: Spatial Analytics

# %% [markdown]
# Content:
# 1. GeoPandas (incl. shapely)
# 1. H3-Library to discretize an area
# 1. Kepler GL to interactively visualize spatial data

# %% [markdown]
# ## GeoPandas:
# Official Documentation: https://geopandas.org/data_structures.html
#
#
# GeoPandas implements two main data structures, a **GeoSeries** and a **GeoDataFrame**.
# These are subclasses of pandas **Series** and **DataFrame**, respectively.

# %% [markdown]
# ### GeoSeries
#
# A GeoSeries is essentially a vector where each entry in the vector is a set of shapes corresponding to one observation.

# %% [markdown]
# #### Geometry Objects
# geopandas has three basic classes of geometric objects (which are actually **shapely** objects):
#
# 1. Points / Multi-Points
# 2. Lines / Multi-Lines
# 3. polygons / Multi-Polygons
#
# Note that all entries in a GeoSeries need not be of the same geometric type, although certain export operations will fail if this is not the case.

# %% [markdown]
# #### Overview of Attributes and Methods
# The GeoSeries class implements nearly all of the attributes and methods of Shapely objects.
# When applied to a GeoSeries, they will apply elementwise to all geometries in the series.
#
# ##### Attributes
#
# * area: shape area (units of projection – see projections)
# * bounds: tuple of max and min coordinates on each axis for each shape
# * total_bounds: tuple of max and min coordinates on each axis for entire GeoSeries
# * geom_type: type of geometry.
# * is_valid: tests if coordinates make a shape that is reasonable geometric shape.
#
# ##### Basic Methods
#
# * distance(): returns Series with minimum distance from each entry to other
# * centroid: returns GeoSeries of centroids
# * representative_point(): returns GeoSeries of points that are guaranteed to be within each geometry. It does NOT * return centroids.
# * to_crs(): change coordinate reference system. See projections
# * plot(): plot GeoSeries. See mapping.
#
#
# ##### Relationship Tests
#
# *  geom_almost_equals(): is shape almost the same as other (good when floating point precision issues make shapes slightly different)
# * contains(): is shape contained within other
# * intersects(): does shape intersect other

# %% [markdown]
# ### GeoDataFrame

# %% [markdown]
# A **GeoDataFrame** is a tabular data structure that contains a GeoSeries.
#
# The most important property of a GeoDataFrame is that it always has **one** GeoSeries column that holds a special status. This GeoSeries is referred to as the GeoDataFrame’s **“geometry”**. When a spatial method is applied to a GeoDataFrame (or a spatial attribute like area is called), this commands will always act on the “geometry” column.

# %% [markdown]
# #### Example

# %%
import geopandas 

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# eyeball geopandas data frame
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
# Plot Spatial Data
world.plot()
# Out:
# <AxesSubplot:>

# %%
# Adjusting the geometry column
world.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
# First rename column, second set geometry column -> You have to set the geometry everytime you change the name.
world = world.rename(columns={'geometry': 'borders'}).set_geometry('borders')

world.geometry.name
# Out:
# 'borders'

# %%
world['centroid_column'] = world.centroid

world.plot()
# Out:
# /var/folders/tm/rzk5w14x43s6q7sgpkq2r7wc0000gn/T/ipykernel_16341/3851898985.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world['centroid_column'] = world.centroid
# <AxesSubplot:>

# %%
# Compute centroid

world['centroid_column'] = world.centroid

world = world.set_geometry('centroid_column')

world.plot()

# note that the active geometry column has changed
# Out:
# /var/folders/tm/rzk5w14x43s6q7sgpkq2r7wc0000gn/T/ipykernel_44503/2696304398.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world['centroid_column'] = world.centroid
# <AxesSubplot:>

# %% [markdown]
# #### Display options

# %%
import geopandas
geopandas.options
# Out:
# Options(
#   display_precision: None [default: None]
#       The precision (maximum number of decimals) of the coordinates in the
#       WKT representation in the Series/DataFrame display. By default (None),
#       it tries to infer and use 3 decimals for projected coordinates and 5
#       decimals for geographic coordinates.
#   use_pygeos: False [default: False]
#       Whether to use PyGEOS to speed up spatial operations. The default is
#       True if PyGEOS is installed, and follows the USE_PYGEOS environment
#       variable if set.
#   )

# %%
# Before changing options 

world['centroid_column'].head()
# Out:
# 0    POINT (163.85316 -17.31631)
# 1      POINT (34.75299 -6.25773)
# 2     POINT (-12.13783 24.29117)
# 3     POINT (-98.14238 61.46908)
# 4    POINT (-112.59944 45.70563)
# Name: centroid_column, dtype: geometry

# %%
# After changing options
geopandas.options.display_precision = 9

world['centroid_column'].head()
# Out:
# 0    POINT (163.853164645 -17.316309426)
# 1      POINT (34.752989855 -6.257732429)
# 2     POINT (-12.137831112 24.291172960)
# 3     POINT (-98.142381372 61.469076145)
# 4    POINT (-112.599435912 45.705628002)
# Name: centroid_column, dtype: geometry

# %% [markdown]
# ### Reading and Writing Files

# %% [markdown]
# Reading Spatial Data
#
# geopandas can read almost any vector-based spatial data format including ESRI shapefile, GeoJSON files and more using the command:

# %% [markdown]
# geopandas.read_file()

# %% [markdown]
# #### Reading big data files by using geometry filters

# %%
# This is our filter
gdf_mask = geopandas.read_file(
    geopandas.datasets.get_path("naturalearth_lowres")
)

# Here we load all cities but apply an filter such that we just get cities that are withing the gdf_mask geometry 
# In this example, we just get cities from Africa
gdf = geopandas.read_file(
    geopandas.datasets.get_path("naturalearth_cities"),
    mask=gdf_mask[gdf_mask.continent=='Africa'],
)

# %%
gdf
# Out:
#              name                            geometry
# 0          Kigali   POINT (30.058585919 -1.951644210)
# 1         Mbabane  POINT (31.133334512 -26.316650778)
# 2            Juba    POINT (31.580025593 4.829975198)
# 3          Banjul  POINT (-16.591701489 13.453876460)
# 4       Bujumbura   POINT (29.360006062 -3.376087220)
# 5            Lome     POINT (1.220811261 6.133882930)
# 6           Tunis   POINT (10.179678099 36.802778136)
# 7          Lusaka  POINT (28.281381736 -15.414698409)
# 8          Harare  POINT (31.042763572 -17.815843836)
# 9         Kampala    POINT (32.581377667 0.318604813)
# 10         Niamey    POINT (2.114710187 13.518651811)
# 11   Bloemfontein  POINT (26.229912881 -29.119993877)
# 12       Pretoria  POINT (28.227483217 -25.704974695)
# 13          Rabat   POINT (-6.836408156 34.025307311)
# 14         Maputo  POINT (32.587217104 -25.953331629)
# 15      Mogadishu    POINT (45.364731752 2.068627193)
# 16       Windhoek  POINT (17.083546101 -22.570006084)
# 17          Abuja     POINT (7.531382143 9.085279008)
# 18         Bissau  POINT (-15.598360841 11.865023823)
# 19         Maseru  POINT (27.483273070 -29.316674379)
# 20   Antananarivo  POINT (47.514678042 -18.914691492)
# 21       Ndjamena   POINT (15.047202455 12.115042395)
# 22         Asmara   POINT (38.933323526 15.333339253)
# 23       Lilongwe  POINT (33.783301960 -13.983295065)
# 24     Libreville     POINT (9.457965046 0.385388610)
# 25     Nouakchott  POINT (-15.975340415 18.086427021)
# 26         Bamako   POINT (-8.001984963 12.651960526)
# 27    Brazzaville   POINT (15.282743634 -4.257239913)
# 28        Conakry   POINT (-13.682180886 9.533468705)
# 29   Yamoussoukro    POINT (-5.275502565 6.818380960)
# 30         Bangui    POINT (18.558288125 4.366644306)
# 31        Yaounde    POINT (11.514704897 3.868646521)
# 32        Cotonou     POINT (2.518044741 6.401954423)
# 33       Gaborone  POINT (25.911947793 -24.646313457)
# 34    Ouagadougou   POINT (-1.526669615 12.372261837)
# 35       Hargeysa    POINT (44.065310017 9.560022399)
# 36       Khartoum   POINT (32.532233380 15.590024084)
# 37  Dar es Salaam   POINT (39.266395978 -6.798066736)
# 38       Monrovia   POINT (-10.799660437 6.314581647)
# 39          Accra    POINT (-0.218661599 5.551980464)
# 40        Abidjan    POINT (-4.041994119 5.321942826)
# 41         Luanda   POINT (13.232481183 -8.836340255)
# 42        Algiers    POINT (3.048606671 36.765010657)
# 43          Dakar  POINT (-17.475075987 14.717777584)
# 44   Johannesburg  POINT (28.028063865 -26.168098881)
# 45       Kinshasa   POINT (15.313026023 -4.327778243)
# 46    Addis Ababa    POINT (38.698058575 9.035256221)
# 47      Cape Town  POINT (18.433042299 -33.918065109)
# 48        Nairobi   POINT (36.814711000 -1.281400883)
# 49          Cairo   POINT (31.248022361 30.051906205)

# %% [markdown]
# #### Writing files

# %%
gdf.to_file("african_cities.shp")

# or as GeoJSON

gdf.to_file("african_cities.geojson", driver='GeoJSON')
# Out:
# /Users/janik/miniconda3/envs/AAA/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /Users/janik/miniconda3/envs/AAA/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# ### Indexing and Selecting Data

# %% [markdown]
# GeoPandas inherits the **standard pandas** methods for indexing/selecting data. This includes label based indexing with .loc and integer position based indexing with .iloc, which apply to both GeoSeries and GeoDataFrame objects. For more information on indexing/selecting, see the pandas documentation.
#
# In addition to the standard pandas methods, GeoPandas also provides **coordinate based indexing** with the cx indexer, which slices using a bounding box. Geometries in the GeoSeries or GeoDataFrame that intersect the bounding box will be returned.
#
# Using the world dataset, we can use this functionality to quickly select all countries whose boundaries extend into the southern hemisphere.

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))


world.plot()
# Out:
# <AxesSubplot:>

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

#xmin, xmax, ymin, ymax 
southern_world = world.cx[10:15, 40:55]

southern_world.plot(figsize=(10, 3));

# %% [markdown]
# ### Making Maps

# %%
# Load Toy data
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

# %%
# Examine world data

world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.000000000 -16.067132664, 1...
# 1  POLYGON ((33.903711197 -0.950000000, 34.072620...
# 2  POLYGON ((-8.665589565 27.656425890, -8.665124...
# 3  MULTIPOLYGON (((-122.840000000 49.000000000, -...
# 4  MULTIPOLYGON (((-122.840000000 49.000000000, -...

# %%
# Plot data
world.plot();

# %% [markdown]
# ## Task 1: Using color schemes to visualize data

# %% [markdown]
# #### Choropleth Maps

# %%
# Plot by GDP per capta
world = world[(world.pop_est>0) & (world.name!="Antarctica")]

world['gdp_per_cap'] = world.gdp_md_est / world.pop_est

world.plot(column='gdp_per_cap', cmap='Reds');

# %% [markdown]
# #### Plotting a legend

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

world.plot(column='pop_est', cmap='Reds', ax=ax, legend=True)
# Out:
# <AxesSubplot:>

# %%
# or horizontally 
fig, ax = plt.subplots(1, 1)
world.plot(column='pop_est', cmap='Reds', ax=ax,legend=True, legend_kwds={'label': "Population by Country",'orientation': "horizontal"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Changing the default coloring

# %%
# By adding a colormap
# Here you can find many colormaps: https://matplotlib.org/3.1.1/tutorials/colors/colormaps.html
world.plot(column='gdp_per_cap', cmap='Greens');

# %%
#### Plotting only the boundaries of geometries
world.boundary.plot()
# Out:
# <AxesSubplot:>

# %%
#### Plotting missing data
import numpy as np

world.loc[np.random.choice(world.index, 40), 'pop_est'] = np.nan

# By default these features are ignored
world.plot(column='pop_est');

# %%
# But we can specfiy a color for missing values
world.plot(column='pop_est', missing_kwds={'color': 'lightgrey'});

# %%
#### Maps with multiple layers (i.e., multiple data sources)

# Second data set 
cities.plot(marker='*', color='green', markersize=5);

cities = cities.to_crs(world.crs)


# Idea: Overlay two plots

# %%
# Plotting two layers
base = world.plot(color='white', edgecolor='black') # This returns an axes object as we have learnt in workshop 2
cities.plot(ax=base, marker='o', color='red', markersize=5);

# %%
# Plot the centroids 
base = world.plot(color='white', edgecolor='black') # This returns an axes object as we have learnt in workshop 2
world.centroid.plot(ax=base, marker='o', color='red', markersize=5);
# Out:
# /var/folders/tm/rzk5w14x43s6q7sgpkq2r7wc0000gn/T/ipykernel_16341/2012049629.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world.centroid.plot(ax=base, marker='o', color='red', markersize=5);

# %%
# or, a more "sophisticated" approach: 
import matplotlib.pyplot as plt


fig, ax = plt.subplots()

world.plot(ax=ax, color='white', edgecolor='black')
cities.plot(ax=ax, marker='o', color='red', markersize=5)




plt.show();

# %% [markdown]
# #### Control the order of multiple layers in a plot

# %%
ax = cities.plot(color='k')
world.plot(ax=ax);

# Not very meaningful visualization.

# %%
ax = cities.plot(color='k', zorder=2)
world.plot(ax=ax, zorder=1);

# Much better

# %% [markdown]
# ### Task 2: Plotting a heatmap of world cities

# %% [markdown]
# #### Heat Map

# %%
def heatmap(d, bins=(50,50), smoothing=1, cmap='jet'):
    # Imports 
    import geopandas as gpd
    import numpy as np
    from scipy import ndimage

    import matplotlib.pylab as pylab
    import matplotlib.pyplot as plt
    
    # Code
    def getx(pt):
        return pt.coords[0][0]

    def gety(pt):
        return pt.coords[0][1]

    x = list(d.geometry.apply(getx))
    y = list(d.geometry.apply(gety))
    heatmap, xedges, yedges = np.histogram2d(y, x, bins=bins)
    extent = [yedges[0], yedges[-1], xedges[-1], xedges[0]]

    logheatmap = np.log(heatmap)
    logheatmap[np.isneginf(logheatmap)] = 0
    logheatmap = ndimage.gaussian_filter(logheatmap, smoothing, mode='nearest')
    
    plt.imshow(logheatmap, cmap=cmap, extent=extent)
    plt.colorbar(location='bottom')
    plt.gca().invert_yaxis()
    plt.show()

heatmap(cities, bins=(250,250))
# Out:
# /var/folders/tm/rzk5w14x43s6q7sgpkq2r7wc0000gn/T/ipykernel_16341/4208131356.py:22: RuntimeWarning: divide by zero encountered in log
#   logheatmap = np.log(heatmap)

# %% [markdown]
# ### Managing Coordinate Reference System
# Coordinate Reference Systems
#
# The Coordinate Reference System (CRS) is important because the geometric shapes in a GeoSeries or GeoDataFrame object are simply a collection of coordinates in an arbitrary space. A CRS tells Python how those coordinates relate to places on the Earth.
#
# You can find the codes for most commonly used projections from www.spatialreference.org.
#
# The same CRS can often be referred to in many ways. For example, one of the most commonly used CRS is the WGS84 latitude-longitude projection. This can be referred to using the authority code "EPSG:4326".

# %% [markdown]
# #### Setting a CRS manually

# %%
# But most of the time we don't need to this because this information is available in the input data.
cities.crs = "EPSG:4326"

# %%
#### Transforming to different projection

world.crs # EPSG:4326 <-> WGS 84 most commonly used system

ax = world.plot()

ax.set_title("WGS84 (lat/lon)");

# %%
# Projecting it to mercator projection
world_merc = world.to_crs("EPSG:3395") 
ax = world_merc.plot()

ax.set_title("Mercator");

# %% [markdown]
# ### Geometric Manipulations

# %% [markdown]
# **GeoSeries.buffer(distance, resolution=16)**
# Returns a GeoSeries of geometries representing all points within a given distance of each geometric object.
#
# **GeoSeries.boundary**
# Returns a GeoSeries of lower dimensional objects representing each geometries’s set-theoretic boundary.
#
# **GeoSeries.centroid**
# Returns a GeoSeries of points for each geometric centroid.
#
# **GeoSeries.convex_hull**
# Returns a GeoSeries of geometries representing the smallest convex Polygon containing all the points in each object unless the number of points in the object is less than three. For two points, the convex hull collapses to a LineString; for 1, a Point.
#
# **GeoSeries.envelope**
# Returns a GeoSeries of geometries representing the point or smallest rectangular polygon (with sides parallel to the coordinate axes) that contains each object.
#
# **GeoSeries.simplify(tolerance, preserve_topology=True)**
# Returns a GeoSeries containing a simplified representation of each object.
#
# **GeoSeries.unary_union**
# Return a geometry containing the union of all geometries in the GeoSeries.
#
#
# ### Affine Transformation
#
# **GeoSeries.affine_transform(self, matrix)**
# Transform the geometries of the GeoSeries using an affine transformation matrix
#
# **GeoSeries.rotate(self, angle, origin='center', use_radians=False)**
# Rotate the coordinates of the GeoSeries.
#
# **GeoSeries.scale(self, xfact=1.0, yfact=1.0, zfact=1.0, origin='center')**
# Scale the geometries of the GeoSeries along each (x, y, z) dimensio.
#
# **GeoSeries.skew(self, angle, origin='center', use_radians=False)**
# Shear/Skew the geometries of the GeoSeries by angles along x and y dimensions.
#
# **GeoSeries.translate(self, xoff=0.0, yoff=0.0, zoff=0.0)**
# Shift the coordinates of the GeoSeries.

# %%
# Create Toy Data

import geopandas
from geopandas import GeoSeries
from shapely.geometry import Polygon
p1 = Polygon([(0, 0), (1, 0), (1, 1)])
p2 = Polygon([(2, 0), (3, 0), (3, 1), (2, 1)])
g = GeoSeries([p1, p2])
g.plot()
# Out:
# <AxesSubplot:>

# %%
# Area of objects
g.area
# Out:
# 0    0.5
# 1    1.0
# dtype: float64

# %%
g.buffer(0.5).plot()
# Out:
# <AxesSubplot:>

# %%
# Example 2: NY districts
nybb_path = geopandas.datasets.get_path('nybb')
boros = geopandas.read_file(nybb_path)
boros.set_index('BoroCode', inplace=True)
boros.sort_index(inplace=True)
boros
# Out:
#                BoroName     Shape_Leng    Shape_Area  \
# BoroCode
# 1             Manhattan  359299.096471  6.364715e+08
# 2                 Bronx  464392.991824  1.186925e+09
# 3              Brooklyn  741080.523166  1.937479e+09
# 4                Queens  896344.047763  3.045213e+09
# 5         Staten Island  330470.010332  1.623820e+09
#
#                                                    geometry
# BoroCode
# 1         MULTIPOLYGON (((981219.055786133 188655.315795...
# 2         MULTIPOLYGON (((1012821.805786133 229228.26458...
# 3         MULTIPOLYGON (((1021176.479003906 151374.79699...
# 4         MULTIPOLYGON (((1029606.076599121 156073.81420...
# 5         MULTIPOLYGON (((970217.022399902 145643.332214...

# %%
# Plot NY districts
boros.plot(cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
# Compute the convex hull
boros['geometry'].convex_hull.plot(cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
#### A more complex operation with random "mobility data":

import numpy as np
from shapely.geometry import Point
xmin, xmax, ymin, ymax = 900000, 1080000, 120000, 280000
xc = (xmax - xmin) * np.random.random(2000) + xmin
yc = (ymax - ymin) * np.random.random(2000) + ymin
pts = GeoSeries([Point(x, y) for x, y in zip(xc, yc)])

# %%
# Compute a buffer around each vehicle
circles = pts.buffer(2000)

# %%
# Compute unary union
mp = circles.unary_union

# %%
type(mp)
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
# This is one single shapley! object. 
mp

# %%
# Computing the intersection 
holes = boros['geometry'].intersection(mp) # N - 1 

holes.plot(cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
# Or the difference
boros_with_holes = boros['geometry'].difference(mp)

boros_with_holes.plot(cmap="Greens")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Set-Operations with Overlay

# %% [markdown]
# When working with multiple spatial datasets – especially multiple polygon or line datasets – users often wish to create new shapes based on places where those datasets overlap (or don’t overlap). These manipulations are often referred using the language of sets – intersections, unions, and differences. These types of operations are made available in the geopandas library through the overlay function.

# %%
from shapely.geometry import Polygon

polys1 = geopandas.GeoSeries([Polygon([(0,0), (2,0), (2,2), (0,2)]),
                              Polygon([(2,2), (4,2), (4,4), (2,4)])])


polys2 = geopandas.GeoSeries([Polygon([(1,1), (3,1), (3,3), (1,3)]),
                              Polygon([(3,3), (5,3), (5,5), (3,5)])])


df1 = geopandas.GeoDataFrame({'geometry': polys1, 'df1':[1,2]})

df2 = geopandas.GeoDataFrame({'geometry': polys2, 'df2':[1,2]})

df1
# Out:
#                                             geometry  df1
# 0  POLYGON ((0.000000000 0.000000000, 2.000000000...    1
# 1  POLYGON ((2.000000000 2.000000000, 4.000000000...    2

# %%
# Plot to y data
ax = df1.plot(color='red');

df2.plot(ax=ax, color='green', alpha=0.5);

# %%
# Union Operator
res_union = geopandas.overlay(df1, df2, how='union')

# %%
res_union.head(10)
# Out:
#    df1  df2                                           geometry
# 0  1.0  1.0  POLYGON ((2.000000000 2.000000000, 2.000000000...
# 1  2.0  1.0  POLYGON ((2.000000000 2.000000000, 2.000000000...
# 2  2.0  2.0  POLYGON ((4.000000000 4.000000000, 4.000000000...
# 3  1.0  NaN  POLYGON ((2.000000000 0.000000000, 0.000000000...
# 4  2.0  NaN  MULTIPOLYGON (((3.000000000 3.000000000, 4.000...
# 5  NaN  1.0  MULTIPOLYGON (((2.000000000 2.000000000, 3.000...
# 6  NaN  2.0  POLYGON ((3.000000000 5.000000000, 5.000000000...

# %%
# Vis. union
ax = res_union.plot(alpha=0.5, cmap='tab10')

# Color the edges
#df1.plot(ax=ax, facecolor='none', edgecolor='k');
#df1.plot(ax=ax, facecolor='none', edgecolor='k');

# %%
ax = df1.plot()
df2.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Task 3: Intersection, Difference, Symmetrical Difference of Geometries

# %%
# Intersection
res_intersection = geopandas.overlay(df1, df2, how='intersection')

ax = res_intersection.plot(cmap='tab10')

df1.plot(ax=ax, facecolor='none', edgecolor='k');

df2.plot(ax=ax, facecolor='none', edgecolor='k');

# %%
# Sym. Difference
res_symdiff = geopandas.overlay(df1, df2, how='symmetric_difference')

ax = res_symdiff.plot(cmap='tab10')

df1.plot(ax=ax, facecolor='none', edgecolor='k');

df2.plot(ax=ax, facecolor='none', edgecolor='k');

# %%
# Difference
res_difference = geopandas.overlay(df1, df2, how='difference')

ax = res_difference.plot(cmap='tab10')

df1.plot(ax=ax, facecolor='none', edgecolor='k');

df2.plot(ax=ax, facecolor='none', edgecolor='k');

# %% [markdown]
# ### Aggregration with dissolve (SQL Equivalent: GroupBy)

# %% [markdown]
# Aggregation with dissolve
#
# Spatial data are often more granular than we need. For example, we might have data on sub-national units, but we’re actually interested in studying patterns at the level of countries.
#
# In a non-spatial setting, when all we need are summary statistics of the data, we aggregate our data using the **groupby** function. But for spatial data, we sometimes also need to aggregate geometric features. In the geopandas library, we can aggregate geometric features using the dissolve function.
#
# dissolve can be thought of as doing three things: (a) it dissolves all the geometries within a given group together into a single geometric feature (using the unary_union method), and (b) it aggregates all the rows of data in a group using groupby.aggregate(), and (c) it combines those two results.

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

world = world[['continent', 'geometry', 'name']]

world.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  177 non-null    object
#  1   geometry   177 non-null    geometry
#  2   name       177 non-null    object
# dtypes: geometry(1), object(2)
# memory usage: 4.3+ KB

# %%
world.head(15)
# Out:
#         continent                                           geometry  \
# 0         Oceania  MULTIPOLYGON (((180.000000000 -16.067132664, 1...
# 1          Africa  POLYGON ((33.903711197 -0.950000000, 34.072620...
# 2          Africa  POLYGON ((-8.665589565 27.656425890, -8.665124...
# 3   North America  MULTIPOLYGON (((-122.840000000 49.000000000, -...
# 4   North America  MULTIPOLYGON (((-122.840000000 49.000000000, -...
# 5            Asia  POLYGON ((87.359970331 49.214980781, 86.598776...
# 6            Asia  POLYGON ((55.968191359 41.308641669, 55.928917...
# 7         Oceania  MULTIPOLYGON (((141.000210403 -2.600151056, 14...
# 8            Asia  MULTIPOLYGON (((141.000210403 -2.600151056, 14...
# 9   South America  MULTIPOLYGON (((-68.634010228 -52.636370459, -...
# 10  South America  MULTIPOLYGON (((-68.634010228 -52.636370459, -...
# 11         Africa  POLYGON ((29.339997593 -4.499983412, 29.519986...
# 12         Africa  POLYGON ((41.585130000 -1.683250000, 40.993000...
# 13         Africa  POLYGON ((39.202220000 -4.676770000, 37.766900...
# 14         Africa  POLYGON ((24.567369012 8.229187934, 23.8058134...
#
#                         name
# 0                       Fiji
# 1                   Tanzania
# 2                  W. Sahara
# 3                     Canada
# 4   United States of America
# 5                 Kazakhstan
# 6                 Uzbekistan
# 7           Papua New Guinea
# 8                  Indonesia
# 9                  Argentina
# 10                     Chile
# 11           Dem. Rep. Congo
# 12                   Somalia
# 13                     Kenya
# 14                     Sudan

# %%
# "GroupBy" Continent and merge geometries
continents = world.dissolve(by='continent')

# %%
# GroupedBy/Dissolved Geometries
continents.head(10)
# Out:
#                                                                   geometry  \
# continent
# Africa                   MULTIPOLYGON (((-11.438779466 6.785916856, -11...
# Antarctica               MULTIPOLYGON (((-61.138975796 -79.981370945, -...
# Asia                     MULTIPOLYGON (((48.679230585 14.003202419, 48....
# Europe                   MULTIPOLYGON (((-53.554839240 2.334896552, -53...
# North America            MULTIPOLYGON (((-155.222170000 19.239720000, -...
# Oceania                  MULTIPOLYGON (((147.914051955 -43.211522312, 1...
# Seven seas (open ocean)  POLYGON ((68.935000000 -48.625000000, 69.58000...
# South America            MULTIPOLYGON (((-68.639990811 -55.580017999, -...
#
#                                            name
# continent
# Africa                                 Tanzania
# Antarctica                           Antarctica
# Asia                                 Kazakhstan
# Europe                                   Russia
# North America                            Canada
# Oceania                                    Fiji
# Seven seas (open ocean)  Fr. S. Antarctic Lands
# South America                         Argentina

# %%
# Population - Continent Level
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

world = world[['continent', 'geometry', 'pop_est']]

continents = world.dissolve(by='continent', aggfunc='sum')

continents.plot(column = 'pop_est', cmap='Greens');

# Equivalent SQL:

# SELECT union(geometry), sum(population) from table naturalearth_lowres group by continent;

# %% [markdown]
# ### Merging Data (SQL Equivalent: Join)

# %% [markdown]
# Both spatial and attribute joins are supported. Attribute joins are done in the same way as in with regular pandas.
#
# Spatial Join are used to join "spatially" related data.

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

# For attribute join
country_shapes = world[['geometry', 'iso_a3']]

country_names = world[['name', 'iso_a3']]

# For spatial join
countries = world[['geometry', 'name']]

countries = countries.rename(columns={'name':'country'})

# %%
# Eyeball cities
cities.head()
# Out:
#            name                           geometry
# 0  Vatican City  POINT (12.453386545 41.903282180)
# 1    San Marino  POINT (12.441770158 43.936095835)
# 2         Vaduz   POINT (9.516669473 47.133723774)
# 3    Luxembourg   POINT (6.130002806 49.611660379)
# 4       Palikir  POINT (158.149974324 6.916643696)

# %%
# Execute spatial join (merge both data frames bases on spatial relationship)
# How: Inner, Left, Right 
# Op: intersects (intersection is not empty), within (is within the other object's interior), contains (contains the other objects)
cities_with_country = geopandas.sjoin(cities, countries, how="inner", op='intersects')
# Out:
# /Users/janik/miniconda3/envs/AAA/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3309: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
cities_with_country.head()
# Out:
#              name                           geometry  index_right  country
# 0    Vatican City  POINT (12.453386545 41.903282180)          141    Italy
# 1      San Marino  POINT (12.441770158 43.936095835)          141    Italy
# 192          Rome  POINT (12.481312563 41.897901485)          141    Italy
# 2           Vaduz   POINT (9.516669473 47.133723774)          114  Austria
# 184        Vienna  POINT (16.364693097 48.201961137)          114  Austria

# %% [markdown]
# #### Missing and Empty Geometries:

# %% [markdown]
# 1. Empty geometries = real geometry objects but with no coordinates (e.g., intersection of polygons without any intersecting point)
# 2. Missing geometries = None values

# %% [markdown]
# ## H3 - Hierarchical Discretization with Hexagons

# %% [markdown]
# # Source:
# 1. https://www.google.com/search?client=safari&rls=en&q=source+h3&ie=UTF-8&oe=UTF-8
# 2. https://eng.uber.com/h3/
# 3. Documentation: https://h3geo.org/#/

# %% [markdown]
# <img src="resources/img1.png">

# %% [markdown]
# <img src="resources/img2.png">

# %% [markdown]
# <img src="resources/img3.png">

# %%
import json
city_bounding_box = geopandas.read_file('./resources/berlin_bounding_box.geojson')
city_bounding_box_json_string = city_bounding_box.to_json()
city_bounding_box_json = json.loads(city_bounding_box_json_string)
city_bounding_box_poly = city_bounding_box_json["features"][0]

# %%
city_bounding_box.plot()
# Out:
# <AxesSubplot:>

# %%
# Valid GeoJSON object
city_bounding_box_poly
# Out:
# {'id': '0',
#  'type': 'Feature',
#  'properties': {},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[13.0133056640625, 52.35715118125809],
#     [13.750762939453125, 52.35715118125809],
#     [13.750762939453125, 52.65222859561964],
#     [13.0133056640625, 52.65222859561964],
#     [13.0133056640625, 52.35715118125809]]]}}

# %%
from h3 import h3 
from shapely.geometry import shape

# Computing hexagons for a given polygon
H3_HEXAGON_RESOLUTION = 9
polygon_obj = city_bounding_box_poly["geometry"] # your geo json object
hexagons = h3.polyfill(polygon_obj, res = H3_HEXAGON_RESOLUTION, geo_json_conformant = True)

# %%
# Returns only the index of each hexagon, not the geometries
hexagons
# Out:
# {'891f1884c7bffff',
#  '891f1d4e42bffff',
#  '891f1896cc3ffff',
#  '891f18b64afffff',
#  '891f1896097ffff',
#  '891f1d4116bffff',
#  '891f18b5d93ffff',
#  '891f18b2447ffff',
#  '891f1d79037ffff',
#  '891f1d4b08fffff',
#  '891f18a66c3ffff',
#  '891f1d593a3ffff',
#  '891f1886c0fffff',
#  '891f18b340fffff',
#  '891f1d4532fffff',
#  '891f1d4964fffff',
#  '891f1d49a13ffff',
#  '891f1d7844bffff',
#  '891f1d4d427ffff',
#  '891f18a2013ffff',
#  '891f18945c3ffff',
#  '891f18a668fffff',
#  '891f1d41b53ffff',
#  '891f1d4c3cfffff',
#  '891f18856b3ffff',
#  '891f1d45dd7ffff',
#  '891f18b3233ffff',
#  '891f1d41293ffff',
#  '891f1d456a7ffff',
#  '891f1880b3bffff',
#  '891f18b365bffff',
#  '891f1d4db3bffff',
#  '891f18b70c3ffff',
#  '891f1d4e1c7ffff',
#  '891f18940d7ffff',
#  '891f1886e13ffff',
#  '891f18846cbffff',
#  '891f18b1203ffff',
#  '891f1d49673ffff',
#  '891f1d4ca67ffff',
#  '891f1d7a24fffff',
#  '891f1896eb7ffff',
#  '891f1d4d16bffff',
#  '891f18b500bffff',
#  '891f18874d3ffff',
#  '891f1d49857ffff',
#  '891f1d4e013ffff',
#  '891f1d4a54bffff',
#  '891f1d4cc53ffff',
#  '891f18b085bffff',
#  '891f1d4e377ffff',
#  '891f1d7a2c7ffff',
#  '891f18b28c7ffff',
#  '891f1d452dbffff',
#  '891f1d48173ffff',
#  '891f18b0467ffff',
#  '891f1d4968fffff',
#  '891f1d49d13ffff',
#  '891f18b187bffff',
#  '891f1d41e8fffff',
#  '891f188764bffff',
#  '891f18b55b7ffff',
#  '891f1d4f397ffff',
#  '891f1896c23ffff',
#  '891f1d4aba7ffff',
#  '891f18b3623ffff',
#  '891f1d48adbffff',
#  '891f1d40927ffff',
#  '891f1d48137ffff',
#  '891f1884567ffff',
#  '891f18b21dbffff',
#  '891f1d45c2bffff',
#  '891f18b5b23ffff',
#  '891f1896c93ffff',
#  '891f18a2617ffff',
#  '891f1886b8fffff',
#  '891f18b18cfffff',
#  '891f1d481cbffff',
#  '891f1d5b22bffff',
#  '891f18b6807ffff',
#  '891f1d4a6a7ffff',
#  '891f1d58c27ffff',
#  '891f1d49b0fffff',
#  '891f18b1ddbffff',
#  '891f18a75d3ffff',
#  '891f1d4991bffff',
#  '891f1d4a403ffff',
#  '891f1886bcbffff',
#  '891f18b76cbffff',
#  '891f18b1367ffff',
#  '891f1896a27ffff',
#  '891f1885d8bffff',
#  '891f18b29dbffff',
#  '891f1d4e5c3ffff',
#  '891f1d58877ffff',
#  '891f18b0d2fffff',
#  '891f1d7b4d7ffff',
#  '891f1d48ad3ffff',
#  '891f18b6027ffff',
#  '891f1d41a5bffff',
#  '891f18863afffff',
#  '891f1d44b43ffff',
#  '891f18b326bffff',
#  '891f1d4b1b3ffff',
#  '891f18b6163ffff',
#  '891f1884037ffff',
#  '891f1d4ee2fffff',
#  '891f1d4b1abffff',
#  '891f1d4e68bffff',
#  '891f1d4e2b7ffff',
#  '891f18ba58bffff',
#  '891f18842abffff',
#  '891f188640fffff',
#  '891f18b5397ffff',
#  '891f1d4595bffff',
#  '891f1d4b4b7ffff',
#  '891f18b734bffff',
#  '891f1896b6fffff',
#  '891f1d7b163ffff',
#  '891f1d45373ffff',
#  '891f1d4f10fffff',
#  '891f18b5aa7ffff',
#  '891f18b214bffff',
#  '891f1d48047ffff',
#  '891f18b1273ffff',
#  '891f18b46bbffff',
#  '891f18b40d7ffff',
#  '891f18b431bffff',
#  '891f18ba493ffff',
#  '891f18b6ccbffff',
#  '891f18b630fffff',
#  '891f18b1643ffff',
#  '891f1d4b65bffff',
#  '891f1886517ffff',
#  '891f18b039bffff',
#  '891f1886a63ffff',
#  '891f1d4e813ffff',
#  '891f1886d97ffff',
#  '891f18940a3ffff',
#  '891f18b026bffff',
#  '891f18b5ca7ffff',
#  '891f1d4f433ffff',
#  '891f1d4e987ffff',
#  '891f18a25cbffff',
#  '891f1d4a8abffff',
#  '891f1d7a4d7ffff',
#  '891f1886053ffff',
#  '891f18b2553ffff',
#  '891f18b7453ffff',
#  '891f1884c4fffff',
#  '891f18b2e73ffff',
#  '891f1d4525bffff',
#  '891f18856a3ffff',
#  '891f18b0537ffff',
#  '891f1d58b37ffff',
#  '891f1d452a3ffff',
#  '891f1d49667ffff',
#  '891f189458fffff',
#  '891f18b09c7ffff',
#  '891f18b1bc7ffff',
#  '891f18b32d7ffff',
#  '891f1d7b4a3ffff',
#  '891f1d4db43ffff',
#  '891f18b287bffff',
#  '891f1884b9bffff',
#  '891f18b6897ffff',
#  '891f1d48207ffff',
#  '891f1d4dbdbffff',
#  '891f1d7b483ffff',
#  '891f1d48e3bffff',
#  '891f18ba513ffff',
#  '891f1d7b133ffff',
#  '891f1d4aca7ffff',
#  '891f1d4d6b7ffff',
#  '891f189698fffff',
#  '891f1880963ffff',
#  '891f18b2e6bffff',
#  '891f1d4a30bffff',
#  '891f18b52a3ffff',
#  '891f18b5083ffff',
#  '891f1d49da7ffff',
#  '891f18b4677ffff',
#  '891f18b154bffff',
#  '891f1886c67ffff',
#  '891f1d7a6abffff',
#  '891f18b08cfffff',
#  '891f18b7523ffff',
#  '891f1d4da33ffff',
#  '891f18b224bffff',
#  '891f18b55abffff',
#  '891f1d4ad7bffff',
#  '891f18b4ea3ffff',
#  '891f1884a2bffff',
#  '891f1d4dc8fffff',
#  '891f1d4a26bffff',
#  '891f18b5b97ffff',
#  '891f18a2cc3ffff',
#  '891f18b421bffff',
#  '891f18b56b7ffff',
#  '891f1d4944bffff',
#  '891f1d49e63ffff',
#  '891f1d43277ffff',
#  '891f18969c3ffff',
#  '891f1884487ffff',
#  '891f1896343ffff',
#  '891f1d48d0fffff',
#  '891f1d4c663ffff',
#  '891f18b595bffff',
#  '891f1d41043ffff',
#  '891f1886383ffff',
#  '891f1d4b68bffff',
#  '891f1d4e28bffff',
#  '891f1d4e313ffff',
#  '891f1d4c50bffff',
#  '891f1887193ffff',
#  '891f1d40a53ffff',
#  '891f1d4eb43ffff',
#  '891f18b09a7ffff',
#  '891f1d4d9dbffff',
#  '891f1d4ac63ffff',
#  '891f1d794afffff',
#  '891f18b4153ffff',
#  '891f1d4ac07ffff',
#  '891f1d4dc53ffff',
#  '891f18b42cbffff',
#  '891f1d48d93ffff',
#  '891f18b2b87ffff',
#  '891f1d4f2cfffff',
#  '891f18b6eafffff',
#  '891f1d4c243ffff',
#  '891f18b7337ffff',
#  '891f1885d7bffff',
#  '891f18b7007ffff',
#  '891f1894ed7ffff',
#  '891f1d59093ffff',
#  '891f18853b3ffff',
#  '891f18b6e33ffff',
#  '891f1d59d6fffff',
#  '891f18b368bffff',
#  '891f1d4abcfffff',
#  '891f18a21a7ffff',
#  '891f1d79577ffff',
#  '891f1d4d1b7ffff',
#  '891f1896aa7ffff',
#  '891f18b2593ffff',
#  '891f1894e87ffff',
#  '891f1886d7bffff',
#  '891f18b1b13ffff',
#  '891f1d45d6bffff',
#  '891f1895ba3ffff',
#  '891f18b2e8bffff',
#  '891f1d59d07ffff',
#  '891f1d4e413ffff',
#  '891f1d4f0d7ffff',
#  '891f1d7a46bffff',
#  '891f1d49567ffff',
#  '891f1884c13ffff',
#  '891f18a2633ffff',
#  '891f1d79687ffff',
#  '891f1d5931bffff',
#  '891f1d4ca03ffff',
#  '891f1d58347ffff',
#  '891f18b0233ffff',
#  '891f18b4227ffff',
#  '891f18b5193ffff',
#  '891f1d4982fffff',
#  '891f18b51cbffff',
#  '891f1d49aa7ffff',
#  '891f1d7b543ffff',
#  '891f18b5637ffff',
#  '891f1d59e2fffff',
#  '891f18b2cd3ffff',
#  '891f1d48037ffff',
#  '891f1d4a597ffff',
#  '891f1d4a42bffff',
#  '891f18b61b7ffff',
#  '891f18b01cbffff',
#  '891f1884373ffff',
#  '891f18b316fffff',
#  '891f18a29b7ffff',
#  '891f18b11b3ffff',
#  '891f1884607ffff',
#  '891f1880b2fffff',
#  '891f1d5948fffff',
#  '891f18b1813ffff',
#  '891f1d4a167ffff',
#  '891f1d7942fffff',
#  '891f1d5823bffff',
#  '891f18b0a83ffff',
#  '891f1d45dcfffff',
#  '891f1d45eb7ffff',
#  '891f1d4cb2bffff',
#  '891f1d45e7bffff',
#  '891f18866cfffff',
#  '891f18b030fffff',
#  '891f18b7677ffff',
#  '891f18b1637ffff',
#  '891f1d4d147ffff',
#  '891f1d499cbffff',
#  '891f18b52d3ffff',
#  '891f18b1123ffff',
#  '891f189638bffff',
#  '891f18863b7ffff',
#  '891f18809c7ffff',
#  '891f18b6a13ffff',
#  '891f1885d87ffff',
#  '891f1885427ffff',
#  '891f1d598c7ffff',
#  '891f1d48bb7ffff',
#  '891f1d41c6fffff',
#  '891f18b615bffff',
#  '891f1d59107ffff',
#  '891f1d49077ffff',
#  '891f1d58843ffff',
#  '891f1d44a7bffff',
#  '891f1d48293ffff',
#  '891f1d48133ffff',
#  '891f1884617ffff',
#  '891f18b643bffff',
#  '891f1884247ffff',
#  '891f1d59ddbffff',
#  '891f1d4d0a3ffff',
#  '891f18849a7ffff',
#  '891f1d4a19bffff',
#  '891f18a240bffff',
#  '891f18b7533ffff',
#  '891f1886313ffff',
#  '891f1d482bbffff',
#  '891f1d5b647ffff',
#  '891f1d7946bffff',
#  '891f1894a3bffff',
#  '891f188648bffff',
#  '891f1d4e6d3ffff',
#  '891f1d456bbffff',
#  '891f1d4e473ffff',
#  '891f1d41e53ffff',
#  '891f18b41b3ffff',
#  '891f1d4a4a7ffff',
#  '891f18b0b03ffff',
#  '891f1d41527ffff',
#  '891f1896aabffff',
#  '891f1d4d907ffff',
#  '891f1894c23ffff',
#  '891f1d41ba3ffff',
#  '891f1d4a55bffff',
#  '891f1d4db33ffff',
#  '891f1d4148bffff',
#  '891f1d7b2a3ffff',
#  '891f1d49ca3ffff',
#  '891f1d45ebbffff',
#  '891f18b0acbffff',
#  '891f18b4a3bffff',
#  '891f1895d83ffff',
#  '891f18b5bc3ffff',
#  '891f1d4a3a7ffff',
#  '891f18b5ac3ffff',
#  '891f1d4d663ffff',
#  '891f1d4145bffff',
#  '891f189410bffff',
#  '891f1d4ce1bffff',
#  '891f18b2527ffff',
#  '891f18b640fffff',
#  '891f18b4e9bffff',
#  '891f1d4f197ffff',
#  '891f1d4e873ffff',
#  '891f1d41663ffff',
#  '891f1d4f14fffff',
#  '891f1884a63ffff',
#  '891f1d4986fffff',
#  '891f1895dbbffff',
#  '891f1895943ffff',
#  '891f1887487ffff',
#  '891f1885913ffff',
#  '891f1d4b563ffff',
#  '891f18ba4bbffff',
#  '891f18b04c3ffff',
#  '891f1895a0fffff',
#  '891f1880db7ffff',
#  '891f1894e47ffff',
#  '891f18b41b7ffff',
#  '891f18958a7ffff',
#  '891f1d58a67ffff',
#  '891f1896327ffff',
#  '891f18875afffff',
#  '891f1d4cc43ffff',
#  '891f1886523ffff',
#  '891f1d4cb07ffff',
#  '891f1d4d8b3ffff',
#  '891f1d792b7ffff',
#  '891f1d792dbffff',
#  '891f1d7948bffff',
#  '891f1d58b13ffff',
#  '891f18b34b3ffff',
#  '891f18b28a3ffff',
#  '891f189486bffff',
#  '891f1d486b7ffff',
#  '891f18b5443ffff',
#  '891f1884e8bffff',
#  '891f1d4c657ffff',
#  '891f18b2dafffff',
#  '891f1d7b6afffff',
#  '891f1d598a3ffff',
#  '891f1d59a73ffff',
#  '891f1d4ce53ffff',
#  '891f1d5884fffff',
#  '891f1887287ffff',
#  '891f1d4e4dbffff',
#  '891f18a21a3ffff',
#  '891f1d4d477ffff',
#  '891f18a7497ffff',
#  '891f188690fffff',
#  '891f188442bffff',
#  '891f1d4ed47ffff',
#  '891f1d4a0d3ffff',
#  '891f18b5dd3ffff',
#  '891f18b5a57ffff',
#  '891f18b260fffff',
#  '891f1d794dbffff',
#  '891f1894d2bffff',
#  '891f188767bffff',
#  '891f18b5dd7ffff',
#  '891f1885567ffff',
#  '891f18b200fffff',
#  '891f1d4507bffff',
#  '891f1d7b5a7ffff',
#  '891f1d41e03ffff',
#  '891f1d49c97ffff',
#  '891f1d4944fffff',
#  '891f1885157ffff',
#  '891f1d4b0abffff',
#  '891f18b4e87ffff',
#  '891f18b5363ffff',
#  '891f1d4a13bffff',
#  '891f1d4a99bffff',
#  '891f1d48b6bffff',
#  '891f18b0363ffff',
#  '891f1d419abffff',
#  '891f18a2413ffff',
#  '891f1d58047ffff',
#  '891f18a20d3ffff',
#  '891f1d7a403ffff',
#  '891f1d59833ffff',
#  '891f1d4ee57ffff',
#  '891f1d4b073ffff',
#  '891f18b46c7ffff',
#  '891f18b006bffff',
#  '891f1d48d53ffff',
#  '891f189652fffff',
#  '891f1d458afffff',
#  '891f1d4cc3bffff',
#  '891f18873c7ffff',
#  '891f18808b3ffff',
#  '891f18b0213ffff',
#  '891f1d48547ffff',
#  '891f18b4c5bffff',
#  '891f18b604fffff',
#  '891f1895c23ffff',
#  '891f1d7b647ffff',
#  '891f1d5947bffff',
#  '891f18b7423ffff',
#  '891f1d49a33ffff',
#  '891f18a75a7ffff',
#  '891f18860bbffff',
#  '891f1d5899bffff',
#  '891f1d48993ffff',
#  '891f1d4aec3ffff',
#  '891f18b6b1bffff',
#  '891f1896873ffff',
#  '891f1d4a52bffff',
#  '891f18b56a7ffff',
#  '891f1d4038bffff',
#  '891f18b20afffff',
#  '891f1d40873ffff',
#  '891f1d790b7ffff',
#  '891f1d4a127ffff',
#  '891f1894853ffff',
#  '891f18959d3ffff',
#  '891f1d452d3ffff',
#  '891f1d45833ffff',
#  '891f1d4e24fffff',
#  '891f1884937ffff',
#  '891f1d5962fffff',
#  '891f18b184bffff',
#  '891f1886463ffff',
#  '891f1d44a67ffff',
#  '891f18b4a97ffff',
#  '891f1d59c0bffff',
#  '891f18b0617ffff',
#  '891f1d4cc5bffff',
#  '891f1d4a843ffff',
#  '891f18b606bffff',
#  '891f1d450bbffff',
#  '891f1894487ffff',
#  '891f1d49ec3ffff',
#  '891f18b352bffff',
#  '891f18b5a0bffff',
#  '891f1d7b1dbffff',
#  '891f18844cbffff',
#  '891f18b600bffff',
#  '891f18b3257ffff',
#  '891f18b5987ffff',
#  '891f1d4ec17ffff',
#  '891f1d48597ffff',
#  '891f1d4868bffff',
#  '891f1d4d2b3ffff',
#  '891f1d4c097ffff',
#  '891f18b63c7ffff',
#  '891f18b6273ffff',
#  '891f1d4cb53ffff',
#  '891f1d486afffff',
#  '891f18b0317ffff',
#  '891f1d4c5cfffff',
#  '891f18b646bffff',
#  '891f1d4d847ffff',
#  '891f1d59d53ffff',
#  '891f18873bbffff',
#  '891f1d4324fffff',
#  '891f1d4ac6bffff',
#  '891f18b048bffff',
#  '891f18b0d43ffff',
#  '891f1d59e7bffff',
#  '891f1d4c31bffff',
#  '891f18b2153ffff',
#  '891f18b7063ffff',
#  '891f1d4904bffff',
#  '891f18b43a3ffff',
#  '891f18b4653ffff',
#  '891f1c2cb63ffff',
#  '891f18b013bffff',
#  '891f18b2cafffff',
#  '891f1885cd7ffff',
#  '891f18a2597ffff',
#  '891f1d4824fffff',
#  '891f1d410b3ffff',
#  '891f1d596a3ffff',
#  '891f1c2c913ffff',
#  '891f1d7908fffff',
#  '891f1886c8fffff',
#  '891f1d49e3bffff',
#  '891f1885dafffff',
#  '891f18b3607ffff',
#  '891f188662bffff',
#  '891f18b5c13ffff',
#  '891f1d4b37bffff',
#  '891f1885407ffff',
#  '891f1d45877ffff',
#  '891f1d4938bffff',
#  '891f18961d7ffff',
#  '891f1886e37ffff',
#  '891f1d4ea4bffff',
#  '891f1d4de2bffff',
#  '891f1d4e513ffff',
#  '891f18b5347ffff',
#  '891f1d4d86fffff',
#  '891f1d44aabffff',
#  '891f1d4d4bbffff',
#  '891f1896b0fffff',
#  '891f1d4ebcfffff',
#  '891f1d4e6bbffff',
#  '891f188412bffff',
#  '891f18b339bffff',
#  '891f1d7911bffff',
#  '891f1d411b3ffff',
#  '891f1886ea7ffff',
#  '891f1d45ccfffff',
#  '891f18b3407ffff',
#  '891f18b4523ffff',
#  '891f1d48c37ffff',
#  '891f18b03a7ffff',
#  '891f1d4ee0fffff',
#  '891f18b05a7ffff',
#  '891f1d58d0bffff',
#  '891f1d40aa3ffff',
#  '891f18b4673ffff',
#  '891f1d40b03ffff',
#  '891f18b5427ffff',
#  '891f1d4510bffff',
#  '891f1d4f64fffff',
#  '891f18b726fffff',
#  '891f1d4c40fffff',
#  '891f18b33c3ffff',
#  '891f1896a4fffff',
#  '891f18b1037ffff',
#  '891f18b1bbbffff',
#  '891f1894437ffff',
#  '891f18b410bffff',
#  '891f18b0c6fffff',
#  '891f1d4b567ffff',
#  '891f188701bffff',
#  '891f18b0b87ffff',
#  '891f188455bffff',
#  '891f18849d3ffff',
#  '891f18b512bffff',
#  '891f1d49a1bffff',
#  '891f1d41dcbffff',
#  '891f18b2acfffff',
#  '891f1d49a43ffff',
#  '891f1d495afffff',
#  '891f1d59dcfffff',
#  '891f1d48163ffff',
#  '891f1d59853ffff',
#  '891f1d4e41bffff',
#  '891f1d59d67ffff',
#  '891f1d485a3ffff',
#  '891f18b1eb3ffff',
#  '891f18b556bffff',
#  '891f1d4b20bffff',
#  '891f1d40b0bffff',
#  '891f1894e93ffff',
#  '891f188400bffff',
#  '891f1d4aab7ffff',
#  '891f18b4a8fffff',
#  '891f1d4b50fffff',
#  '891f1d49147ffff',
#  '891f1895827ffff',
#  '891f188739bffff',
#  '891f18b094fffff',
#  '891f18b550fffff',
#  '891f1886c47ffff',
#  '891f1d793a7ffff',
#  '891f1d4b0c3ffff',
#  '891f18b62afffff',
#  '891f1d48eb3ffff',
#  '891f18b43d7ffff',
#  '891f1d4f443ffff',
#  '891f1d4ea4fffff',
#  '891f1d4e60bffff',
#  '891f1d4922fffff',
#  '891f18b733bffff',
#  '891f18b2993ffff',
#  '891f1d494afffff',
#  '891f1886163ffff',
#  '891f1d79573ffff',
#  '891f1d41b3bffff',
#  '891f1d78693ffff',
#  '891f18b6b4bffff',
#  '891f18b2a53ffff',
#  '891f18b315bffff',
#  '891f1d7b2a7ffff',
#  '891f18848cbffff',
#  '891f18b11abffff',
#  '891f18a64c7ffff',
#  '891f18b65cbffff',
#  '891f1d593cbffff',
#  '891f1d58067ffff',
#  '891f1d58283ffff',
#  '891f1880ba3ffff',
#  '891f1886dcfffff',
#  '891f1886657ffff',
#  '891f189423bffff',
#  '891f18858abffff',
#  '891f1896c5bffff',
#  '891f1d4edabffff',
#  '891f18948afffff',
#  '891f1d4847bffff',
#  '891f1d48e8fffff',
#  '891f1880817ffff',
#  '891f1884d33ffff',
#  '891f1884e07ffff',
#  '891f1d58bd7ffff',
#  '891f18b43b3ffff',
#  '891f189495bffff',
#  '891f1d4b3c7ffff',
#  '891f18b440bffff',
#  '891f18b5d8fffff',
#  '891f1d41d27ffff',
#  '891f18872c3ffff',
#  '891f188497bffff',
#  '891f1d4acbbffff',
#  '891f1d4f057ffff',
#  '891f1d7a26fffff',
#  '891f18b4c77ffff',
#  '891f1d49e9bffff',
#  '891f1d79213ffff',
#  '891f1d599d3ffff',
#  '891f1d58ba7ffff',
#  '891f1d4c68fffff',
#  '891f189608fffff',
#  '891f1d58623ffff',
#  '891f1d41c9bffff',
#  '891f1885c6bffff',
#  '891f1896d9bffff',
#  '891f1d492b3ffff',
#  '891f1d41d07ffff',
#  '891f1d4da3bffff',
#  '891f18b14abffff',
#  '891f1884dcfffff',
#  '891f1d5896bffff',
#  '891f1d41283ffff',
#  '891f188725bffff',
#  '891f1d4dcd7ffff',
#  '891f18b4613ffff',
#  '891f18840cfffff',
#  '891f18b5c9bffff',
#  '891f1d79277ffff',
#  '891f18b146bffff',
#  '891f1d4ada3ffff',
#  '891f1d49927ffff',
#  '891f18b2037ffff',
#  '891f1d4e1c3ffff',
#  '891f1d49ea7ffff',
#  '891f1895c33ffff',
#  '891f1d58ac7ffff',
#  '891f18b36c7ffff',
#  '891f1d45ecfffff',
#  '891f18b1477ffff',
#  '891f1d7b4d3ffff',
#  '891f18a2993ffff',
#  '891f1d59e27ffff',
#  '891f1885667ffff',
#  '891f1886d5bffff',
#  '891f18b3457ffff',
#  '891f1d491afffff',
#  '891f18b2d33ffff',
#  '891f18940cfffff',
#  '891f1880937ffff',
#  '891f18b6e73ffff',
#  '891f1d4adcbffff',
#  '891f1d4a4cfffff',
#  '891f1887477ffff',
#  '891f18861afffff',
#  '891f1884867ffff',
#  '891f1884097ffff',
#  '891f18b6c03ffff',
#  '891f1d48973ffff',
#  '891f1d4d3dbffff',
#  '891f18b2d73ffff',
#  '891f18874bbffff',
#  '891f1d4de97ffff',
#  '891f18b728fffff',
#  '891f18b20a7ffff',
#  '891f18b51b3ffff',
#  '891f18b54abffff',
#  '891f1c2c993ffff',
#  '891f1d4f04bffff',
#  '891f1880b23ffff',
#  '891f1d5983bffff',
#  '891f1d4e227ffff',
#  '891f188426bffff',
#  '891f18b7247ffff',
#  '891f1d4538fffff',
#  '891f1d5958bffff',
#  '891f1d483b3ffff',
#  '891f1d7921bffff',
#  '891f1d4d9b7ffff',
#  '891f18b00b3ffff',
#  '891f1d598d3ffff',
#  '891f1d7950bffff',
#  '891f1d595afffff',
#  '891f1d41193ffff',
#  '891f1d489c7ffff',
#  '891f1d4334bffff',
#  '891f1d45a93ffff',
#  '891f1d49c93ffff',
#  '891f1d4ddd7ffff',
#  '891f1d4818fffff',
#  '891f1d5999bffff',
#  '891f18b5cb3ffff',
#  '891f18b100bffff',
#  '891f18b1277ffff',
#  '891f18b5a6bffff',
#  '891f1d7926bffff',
#  '891f1d492a3ffff',
#  '891f1d588d7ffff',
#  '891f1d4c583ffff',
#  '891f1d4c4dbffff',
#  '891f1d7a21bffff',
#  '891f18b5a73ffff',
#  '891f1d48e17ffff',
#  '891f1d5b3cbffff',
#  '891f18b292fffff',
#  '891f1d58e73ffff',
#  '891f1d49917ffff',
#  '891f18a25d3ffff',
#  '891f1887523ffff',
#  '891f18b1517ffff',
#  '891f1d48963ffff',
#  '891f1886213ffff',
#  '891f18b6407ffff',
#  '891f1d7a63bffff',
#  '891f1d59aafffff',
#  '891f1d496bbffff',
#  '891f1d45dafffff',
#  '891f1d4dcc3ffff',
#  '891f18b6507ffff',
#  '891f18b594bffff',
#  '891f1d7b00fffff',
#  '891f18b7257ffff',
#  '891f18b5103ffff',
#  '891f1d4d25bffff',
#  '891f1d4a34bffff',
#  '891f1894d97ffff',
#  '891f1d45b1bffff',
#  '891f1d48803ffff',
#  '891f1885283ffff',
#  '891f1d581cbffff',
#  '891f1d7b423ffff',
#  '891f18b4063ffff',
#  '891f18b6887ffff',
#  '891f18b3343ffff',
#  '891f1d4ed07ffff',
#  '891f18b36a3ffff',
#  '891f1885e9bffff',
#  '891f18b2d0bffff',
#  '891f1895a23ffff',
#  '891f1d48b77ffff',
#  '891f18b1ab7ffff',
#  '891f1d4986bffff',
#  '891f1880b47ffff',
#  '891f1894d6fffff',
#  '891f18b6aabffff',
#  '891f18b0eabffff',
#  '891f1d58a17ffff',
#  '891f1d41b67ffff',
#  '891f1d414a3ffff',
#  '891f1d4864bffff',
#  '891f1d4e237ffff',
#  '891f1d45b8bffff',
#  '891f1895c6bffff',
#  '891f1d4e903ffff',
#  '891f1d4f04fffff',
#  '891f18b6263ffff',
#  '891f1d4f647ffff',
#  '891f18b0d93ffff',
#  '891f1d4d40fffff',
#  '891f1896d47ffff',
#  '891f1d4dd67ffff',
#  '891f18b556fffff',
#  '891f18b1803ffff',
#  '891f18b5863ffff',
#  '891f18b1e47ffff',
#  '891f1d481b7ffff',
#  '891f1d4b29bffff',
#  '891f1d41a6fffff',
#  '891f18a2d93ffff',
#  '891f18b4333ffff',
#  '891f1884ca7ffff',
#  '891f1d44ad7ffff',
#  '891f1d4a063ffff',
#  '891f18b6b53ffff',
#  '891f18b2bb3ffff',
#  '891f18944bbffff',
#  '891f18b5817ffff',
#  '891f1d7b27bffff',
#  '891f1894d17ffff',
#  '891f1d7956fffff',
#  '891f1d7b0b7ffff',
#  '891f18b2ccbffff',
#  '891f18b7687ffff',
#  '891f18b5057ffff',
#  '891f1d7b627ffff',
#  '891f188744fffff',
#  '891f1885197ffff',
#  '891f1d4ea9bffff',
#  '891f1884177ffff',
#  '891f18b18cbffff',
#  '891f1d4daabffff',
#  '891f1d4e293ffff',
#  '891f1d58033ffff',
#  '891f18ba41bffff',
#  '891f1d4f3dbffff',
#  '891f1d7865bffff',
#  '891f1886303ffff',
#  '891f1d59a37ffff',
#  '891f18963a3ffff',
#  '891f1d5920fffff',
#  '891f18b3157ffff',
#  '891f18b266bffff',
#  '891f18b2243ffff',
#  '891f18b29cfffff',
#  '891f18b4177ffff',
#  '891f1d49a73ffff',
#  '891f1885ccfffff',
#  '891f18b2a43ffff',
#  '891f1d4ce8fffff',
#  '891f1d45e53ffff',
#  '891f18b5cdbffff',
#  '891f1896b0bffff',
#  '891f18b1d6bffff',
#  '891f1d4d17bffff',
#  '891f18b03bbffff',
#  '891f18b59cfffff',
#  '891f1d402d7ffff',
#  '891f1d40e67ffff',
#  '891f18b7323ffff',
#  '891f18b430bffff',
#  '891f1d4140bffff',
#  '891f18b7307ffff',
#  '891f1d43367ffff',
#  '891f18b5977ffff',
#  '891f188742fffff',
#  '891f1d41623ffff',
#  '891f18b6453ffff',
#  '891f18b72a3ffff',
#  '891f1d7a40bffff',
#  '891f1d59c53ffff',
#  '891f18b5477ffff',
#  '891f18b72bbffff',
#  '891f1d4c113ffff',
#  '891f1d40a0fffff',
#  '891f1d41cb3ffff',
#  '891f189497bffff',
#  '891f1d4dd53ffff',
#  '891f1d4e17bffff',
#  '891f1d43267ffff',
#  '891f1896ccfffff',
#  '891f1d4cd0bffff',
#  '891f1d4aeb3ffff',
#  '891f1d48a6bffff',
#  '891f1d4de23ffff',
#  '891f1d4c483ffff',
#  '891f18b0183ffff',
#  '891f1d4f3afffff',
#  '891f1d5b277ffff',
#  '891f1d7965bffff',
#  '891f1d4f5cbffff',
#  '891f1882927ffff',
#  '891f1d4f03bffff',
#  '891f1d4ad9bffff',
#  '891f1d5946bffff',
#  '891f1d4d0a7ffff',
#  '891f18b4373ffff',
#  '891f1d4868fffff',
#  '891f1d4d4a3ffff',
#  '891f1d5b367ffff',
#  '891f18a259bffff',
#  '891f1d49973ffff',
#  '891f1d588dbffff',
#  '891f18b34c3ffff',
#  '891f1d7b5c3ffff',
#  '891f1d4d0afffff',
#  '891f1d4b01bffff',
#  '891f1d49243ffff',
#  '891f1885997ffff',
#  '891f18ba4cbffff',
#  '891f1d7934fffff',
#  '891f1d41937ffff',
#  '891f188291bffff',
#  '891f1d4a907ffff',
#  '891f1d59827ffff',
#  '891f1d4564bffff',
#  '891f1d5956bffff',
#  '891f1882963ffff',
#  '891f1d59b8bffff',
#  '891f1886593ffff',
#  '891f1d48da3ffff',
#  '891f1895977ffff',
#  '891f1d451cfffff',
#  '891f18b536bffff',
#  '891f1d453c3ffff',
#  '891f1d499abffff',
#  '891f1d7a627ffff',
#  '891f1d58c6fffff',
#  '891f1d4b607ffff',
#  '891f1d48263ffff',
#  '891f1d49d57ffff',
#  '891f1884907ffff',
#  '891f1d5817bffff',
#  '891f1d4f6b3ffff',
#  '891f18b24cbffff',
#  '891f1d49c7bffff',
#  '891f18b2a97ffff',
#  '891f1d4acb3ffff',
#  '891f1d4c5abffff',
#  '891f1d4ab97ffff',
#  '891f1885d53ffff',
#  '891f1d419dbffff',
#  '891f1d41bd7ffff',
#  '891f1d450c7ffff',
#  '891f1d41ecbffff',
#  '891f1d41b8bffff',
#  '891f1d59d77ffff',
#  '891f1d4e0a7ffff',
#  '891f18b4c2fffff',
#  '891f1d784cbffff',
#  '891f1d4a007ffff',
#  '891f1885437ffff',
#  '891f1d49e43ffff',
#  '891f1d793c7ffff',
#  '891f188416fffff',
#  '891f188702fffff',
#  '891f1d4d68bffff',
#  '891f1d418c7ffff',
#  '891f18b4abbffff',
#  '891f1d4ae07ffff',
#  '891f188508fffff',
#  '891f1885c4fffff',
#  '891f18b230fffff',
#  '891f1d4e08bffff',
#  '891f1d4a387ffff',
#  '891f1d79377ffff',
#  '891f18b25cbffff',
#  '891f189655bffff',
#  '891f1896d63ffff',
#  '891f1894ac3ffff',
#  '891f18a20afffff',
#  '891f1895c03ffff',
#  '891f1d415cfffff',
#  '891f1d4e98fffff',
#  '891f188548bffff',
#  ...}

# %%
# Convert H3 Indexes to Geometry Objects

# Create geo data frame
df = geopandas.GeoDataFrame(list(hexagons), columns=['h3_hex_id'], crs="EPSG:4326")

df['geometry'] = df[(df['h3_hex_id'].notna())].apply(lambda row: shape({"type": "Polygon",
                                           "coordinates": [h3.h3_to_geo_boundary(row["h3_hex_id"], geo_json=True)],
                                           "properties": ""
                                           }), axis=1)
# Out:
# /var/folders/tm/rzk5w14x43s6q7sgpkq2r7wc0000gn/T/ipykernel_16341/308284276.py:4: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   df = geopandas.GeoDataFrame(list(hexagons), columns=['h3_hex_id'], crs="EPSG:4326")

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Get the hexagon for a data point
# Assume we have a dataframe with a column for latitude and longitude representing "point data".
import pandas as pd
from shapely.geometry.polygon import Polygon
trips = pd.read_csv('resources/trips.csv')

# %%
trips
# Out:
#                                                       id   provider  \
# 0                       YmlrZTo6Y2FsbGFiaWtlOjoxNzgyNDM=  callabike
# 1                                          16268nextbike   nextbike
# 2                                          16305nextbike   nextbike
# 3                                          15361nextbike   nextbike
# 4                                          14529nextbike   nextbike
# ...                                                  ...        ...
# 17459  ZnJlZWZsb2F0Ojpkcml2ZW5vdzo6V01XV0c3MTAzMDNFNT...   drivenow
# 17460   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzIyNjY3     car2go
# 17461  ZnJlZWZsb2F0Ojpkcml2ZW5vdzo6V01XWFM1MTAyMDJIMT...   drivenow
# 17462  ZnJlZWZsb2F0Ojpkcml2ZW5vdzo6V01XWE01MTA0MDJIMj...   drivenow
# 17463   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjgxMjk5     car2go
#
#       vehicleType             datetime_start               datetime_end  \
# 0         bicycle  2019-10-13 09:43:08+02:00  2019-10-13 10:18:07+02:00
# 1         bycicle  2019-10-14 11:52:00+02:00  2019-10-14 12:35:00+02:00
# 2         bycicle  2020-01-13 11:28:00+01:00  2020-01-13 12:02:00+01:00
# 3         bycicle  2019-10-06 21:51:00+02:00  2019-10-06 22:14:00+02:00
# 4         bycicle  2019-10-12 17:55:00+02:00  2019-10-12 18:45:00+02:00
# ...           ...                        ...                        ...
# 17459         car  2019-12-16 18:53:26+01:00  2019-12-16 19:23:09+01:00
# 17460         car  2019-12-06 13:18:46+01:00  2019-12-06 14:03:07+01:00
# 17461         car  2019-11-29 16:38:28+01:00  2019-11-29 18:58:07+01:00
# 17462         car  2019-10-02 09:23:08+02:00  2019-10-02 10:03:07+02:00
# 17463         car  2019-12-15 15:23:08+01:00  2019-12-15 15:58:07+01:00
#
#        longitude_start  latitude_start  longitude_end  latitude_end
# 0            13.373544       52.509953      13.390235     52.489727
# 1            13.406048       52.524962      13.399155     52.504241
# 2            13.394186       52.507561      13.325732     52.462790
# 3            13.418204       52.490397      13.376718     52.487904
# 4            13.416839       52.549147      13.444498     52.485126
# ...                ...             ...            ...           ...
# 17459        13.297930       52.500898      13.270539     52.510636
# 17460        13.374310       52.507060      13.300790     52.513520
# 17461        13.322898       52.511216      13.321236     52.511161
# 17462        13.325170       52.501885      13.439742     52.500465
# 17463        13.374700       52.511630      13.385930     52.445040
#
# [17464 rows x 9 columns]

# %%
# Get the hexagon for a data point
# Assume we have a dataframe with a column for latitude and longitude representing "point data".
import pandas as pd
from shapely.geometry.polygon import Polygon
trips = pd.read_csv('resources/trips.csv')

H3_HEXAGON_RESOLUTION = 8

trips["h3_hex_id_start"] = trips.apply(lambda row: h3.geo_to_h3(row["latitude_start"], row["longitude_start"], H3_HEXAGON_RESOLUTION) if (row['latitude_start'] and row['longitude_start']) else 0, axis=1)
# trips["h3_hex_id_end"] = trips.apply(lambda row: h3.geo_to_h3(row["latitude_start"], row["longitude_end"], H3_HEXAGON_RESOLUTION) if (row['latitude_end'] and row['longitude_end']) else 0, axis=1)

trips_starts = pd.DataFrame()
trips_starts = trips.groupby('h3_hex_id_start').count()['id'].reset_index().rename(columns={'id': 'count'})
trips_starts['geometry'] = trips_starts.apply(lambda x: Polygon(h3.h3_to_geo_boundary(x["h3_hex_id_start"], geo_json=True)), axis=1)

trips_starts_geo = geopandas.GeoDataFrame(trips_starts, geometry=trips_starts['geometry'], crs='EPSG:4326')

# %%
trips_starts_geo.plot(column='count', cmap='Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Interactive Visualization with Kepler.GL

# %% [markdown]
# Source: https://kepler.gl

# %%
trips_starts_geo.to_file('trips.geojson')
# Out:
# /Users/janik/miniconda3/envs/AAA/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
